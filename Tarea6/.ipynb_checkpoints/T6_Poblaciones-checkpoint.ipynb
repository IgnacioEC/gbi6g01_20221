# %%
import scipy as spy
import poblacionmendeliana as pobmen

# %%
pobmen.build_population(500, 0.50) # Visualización proporcional de la Función 1
# Out:
# [('a', 'A'),
#  ('A', 'A'),
#  ('a', 'a'),
#  ('A', 'a'),
#  ('A', 'A'),
#  ('a', 'A'),
#  ('a', 'a'),
#  ('A', 'a'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('A', 'a'),
#  ('A', 'A'),
#  ('A', 'a'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('A', 'a'),
#  ('A', 'A'),
#  ('a', 'A'),
#  ('A', 'a'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('A', 'a'),
#  ('A', 'A'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('A', 'a'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'a'),
#  ('a', 'A'),
#  ('a', 'a'),
#  ('A', 'A'),
#  ('A', 'a'),
#  ('A', 'a'),
#  ('a', 'A'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('a', 'a'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('A', 'a'),
#  ('A', 'a'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('a', 'a'),
#  ('a', 'a'),
# ...

# %%
my_pop = pobmen.build_population(500, 0.50) # La proporción obtenida anteriormente la renombramos como my-pop

# %%
fmy_pop = pobmen.compute_frequencies(my_pop) # Ejecutamos la función 2 y renombramos como fmy_pop
print(fmy_pop)
print((500-fmy_pop["aa"])/500)
# Out:
# {'AA': 133, 'aa': 120, 'Aa': 114, 'aA': 133}
# 0.76

# %%
#falta hacer el bucle
